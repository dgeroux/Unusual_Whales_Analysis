# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
option_data_to_load = "Resources/jan_2022_data.csv"

# Read the City and Ride Data
option_data_df = pd.read_csv(option_data_to_load)
option_data_df
# Out:
#           Date Ticker Strike Call/Put Expiration     DTE Underlying  \
# 0     1/3/2022    SPY   $485     call  1/21/2022  (-81d)   $477.23
# 1     1/3/2022   AMGN   $240     call  4/14/2022    (2d)   $222.97
# 2     1/3/2022    IGT    $32     call  4/14/2022    (2d)    $29.62
# 3     1/3/2022   HOOD    $17      put  5/20/2022   (38d)    $18.71
# 4     1/3/2022    IWM   $222      put  1/21/2022  (-81d)   $225.90
# ..         ...    ...    ...      ...        ...     ...        ...
# 862  1/31/2022    SPY   $460     call  2/18/2022  (-53d)   $449.48
# 863  1/31/2022    SPY   $460     call  2/18/2022  (-53d)   $450.11
# 864  1/31/2022    IWM   $195      put  2/18/2022  (-53d)   $200.99
# 865        NaN    NaN    NaN      NaN        NaN     NaN        NaN
# 866        NaN    NaN    NaN      NaN        NaN     NaN        NaN
#
#            Bid-Ask    Spot    Size Premium Open Interest Volume
# 0    $1.62 - $1.64  $1.64   10,000  $1.64M         17.3K  10.9K
# 1    $2.94 - $3.10  $3.10    4,500   $1.4M           412     5K
# 2    $2.08 - $2.44  $2.44    5,944  $1.45M           10K   6.9K
# 3    $2.97 - $3.10  $3.10    9,000  $2.79M           512     9K
# 4    $2.51 - $2.53  $2.55    3,955  $1.01M         10.5K   4.2K
# ..             ...     ...     ...     ...           ...    ...
# 862  $3.43 - $3.45  $3.45    5,000  $1.73M         32.2K  27.6K
# 863  $3.60 - $3.62  $3.63    5,000  $1.82M         32.2K  32.8K
# 864  $3.32 - $3.36  $3.35    3,000     $1M         28.2K   7.9K
# 865            NaN     NaN     NaN     NaN           NaN    NaN
# 866            NaN     NaN     NaN     NaN           NaN    NaN
#
# [867 rows x 13 columns]
